# %%
# 전국 어린이집 종류에 따른 갯수?

d = read.csv('day_care_center.csv')
head(d)
# Out:
#   city       gu       day_care_name    day_care_type day_care_baby_num
# 1 서울특별시 서대문구 가람어린이집     국공립        70
# 2 서울특별시 서대문구 가좌제일어린이집 국공립        88
# 3 서울특별시 서대문구 경찰청어린이집   직장          90
# 4 서울특별시 서대문구 고운햇살어린이집 가정          18
# 5 서울특별시 서대문구 고은어린이집     국공립        93
# 6 서울특별시 서대문구 그루터기어린이집 가정          19
#   teacher_num nursing_room_num playground_num CCTV_num is_commuting_vehicle
# 1 11          5                1               7       N
# 2 22          5                2              10       N
# 3 23          6                1              32       N
# 4  5          3                0               4       N
# 5 20          7                2              10       N
# 6  3          3                0               4       N
#   reference_date
# 1 2018-07-31
# 2 2018-07-31
# 3 2018-07-31
# 4 2018-07-31
# 5 2018-07-31
# 6 2018-07-31

# %%
# 결측치
d[!complete.cases(d),]
# Out:
#      city       gu     day_care_name          day_care_type day_care_baby_num
# 155  서울특별시 도봉구 꼬마숲둥지어린이집     민간           49
# 156  서울특별시 도봉구 방학가람어린이집       국공립         88
# 158  서울특별시 도봉구 서원어린이집           국공립         47
# 159  서울특별시 도봉구 노아어린이집           민간           33
# 160  서울특별시 도봉구 고은햇살어린이집       가정           14
# 161  서울특별시 도봉구 맑은숲어린이집         가정           11
# 162  서울특별시 도봉구 햇살어린이집           가정           14
# 163  서울특별시 도봉구 키즈딸기어린이집       민간           49
# 164  서울특별시 도봉구 하나어린이집           민간           41
# 165  서울특별시 도봉구 햇살마루어린이집       민간           65
# 166  서울특별시 도봉구 행복한어린이집         민간           57
# 167  서울특별시 도봉구 웃음가득해피어린이집   가정           18
# 168  서울특별시 도봉구 노벨어린이집           민간           56
# 169  서울특별시 도봉구 노엘어린이집           민간           63
# 170  서울특별시 도봉구 누리어린이집           민간           58
# 171  서울특별시 도봉구 다온어린이집           민간           82
# 172  서울특별시 도봉구 동화어린이집           민간           71
# 173  서울특별시 도봉구 둘리어린이집           민간           30
# ...

# %%
d <- na.omit(d);d
# Out:
#      city       gu       day_care_name            day_care_type
# 1    서울특별시 서대문구 가람어린이집             국공립
# 2    서울특별시 서대문구 가좌제일어린이집         국공립
# 3    서울특별시 서대문구 경찰청어린이집           직장
# 4    서울특별시 서대문구 고운햇살어린이집         가정
# 5    서울특별시 서대문구 고은어린이집             국공립
# 6    서울특별시 서대문구 그루터기어린이집         가정
# 7    서울특별시 서대문구 금화어린이집             국공립
# 8    서울특별시 서대문구 꼬꼬마어린이집           가정
# 9    서울특별시 서대문구 꼬마박사어린이집         가정
# 10   서울특별시 서대문구 꼬마숲어린이집           가정
# 11   서울특별시 서대문구 꾸러기어린이집           가정
# 12   서울특별시 서대문구 꿈빛나무어린이집         국공립
# 13   서울특별시 서대문구 꿈사랑어린이집           민간
# 14   서울특별시 서대문구 꿈하은어린이집           가정
# 15   서울특별시 서대문구 나빛어린이집             가정
# 16   서울특별시 서대문구 다솜어린이집             국공립
# 17   서울특별시 서대문구 단비어린이집             가정
# 18   서울특별시 서대문구 대신어린이집             법인·단체
# 19   서울특별시 서대문구 독립문어린이집           민간
# 20   서울특별시 서대문구 돈의문어린이집           국공립
# 21   서울특별시 서대문구 동방어린이집             국공립
# 22   서울특별시 서대문구 동우어린이나라어린이집   민간
# 23   서울특별시 서대문구 두란노어린이집           민간
# ...

# %%
d[d$city == '서울특별시',]
d[d$city == '부산광역시',]
# Out:
# [1] 5656
# [1] 1895
